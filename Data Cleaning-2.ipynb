# %% [markdown]
# # Bengaluru Restaurant Analysis A Zomato Dataset Exploration

# %% [markdown]
# ## Data Cleaning - 2

# %%
import pandas as pd

# %%
clean1=pd.read_csv(r"C:\Users\deepa\OneDrive\Desktop\Data Analytics\Project\zomato partially cleaned.csv")

# %%
pd.set_option("display.max_rows",None)

# %% [markdown]
# ### Removing the the Rows with Null Values

# %%
clean1.dropna(axis='index',how='any',subset=['name','ratings','phone','cuisines','dish liked','resting','location','approx cost'],inplace=True)

# %%
clean1.head(100)
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1             1  https://www.zomato.com/bangalore/spice-elephan...
# 2             2  https://www.zomato.com/SanchurroBangalore?cont...
# 3             3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4             4  https://www.zomato.com/bangalore/grand-village...
# 5             5  https://www.zomato.com/bangalore/timepass-dinn...
# 7             7  https://www.zomato.com/bangalore/onesta-banash...
# 8             8  https://www.zomato.com/bangalore/penthouse-caf...
# 9             9  https://www.zomato.com/bangalore/smacznego-ban...
# 10           10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11           11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12           12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13           13  https://www.zomato.com/bangalore/caf-eleven-ba...
# ...

# %%
clean1.count()
# Out:
# Unnamed: 0      1147
# url             1147
# address         1118
# name            1147
# online order    1147
# book table      1147
# ratings         1147
# votes           1147
# phone           1147
# location        1147
# resting         1147
# dish liked      1147
# cuisines        1147
# approx cost     1147
# reviews         1134
# menu             286
# type            1147
# city             931
# dtype: int64

# %%
clean1.to_csv(r"C:\Users\deepa\OneDrive\Desktop\Data Analytics\Project\zomato cleaned.csv")
